# %% [markdown]
# <a href="https://colab.research.google.com/github/Penn2001/Hands-On-Data-Analysis-with-Pandas/blob/master/Participation_Activity_Week9_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Opens the Python supplied web browser library
#See https://docs.python.org/3/library/webbrowser.html?highlight=webbrowser#module-webbrowser
#Opens the third party requests library.
# See https://requests.readthedocs.io/en/latest/user/quickstart/
import webbrowser
import requests

# %%
r = requests.get('https://api.github.com/events')
#Return status coe of 200 tells us that the request was successful.
r.status_code
# Out:
# 200

# %%
#Print the content of the request, i.e. requests.get
r.text
# Out:
# '[{"id":"43613822154","type":"IssuesEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":878375331,"name":"kysports-cn/kytiyucom","url":"https://api.github.com/repos/kysports-cn/kytiyucom"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/kysports-cn/kytiyucom/issues/75733","repository_url":"https://api.github.com/repos/kysports-cn/kytiyucom","labels_url":"https://api.github.com/repos/kysports-cn/kytiyucom/issues/75733/labels{/name}","comments_url":"https://api.github.com/repos/kysports-cn/kytiyucom/issues/75733/comments","events_url":"https://api.github.com/repos/kysports-cn/kytiyucom/issues/75733/events","html_url":"https://github.com/kysports-cn/kytiyucom/issues/75733","id":2641978900,"node_id":"I_kwDONFrxo86deWYU","number":75733,"title":"🤕欧冠第四轮各队伤病情况汇总：坎帕佐解禁复出 科尔克马兹
# ...

# %%
r.headers['content-type']
'application/json; charset=utf8'
r.encoding
'utf-8'
r.text
'{"type":"User"...'
r.json()
{'private_gists': 419, 'total_private_repos': 77}
# Out:
# {'private_gists': 419, 'total_private_repos': 77}

# %%
file = open("/content/drive/MyDrive/MSSP607/Modules/Week09/Photos/GIT_Events", "wb")
file.write(r.content)
file.close()

# %%
r = requests.get('https://www.bc3analytics.com/wp-content/uploads/2020/04/shutterstock_1135978331.jpg')
r.status_code == requests.codes.ok
# Out:
# True

# %%
#open a file for writing (w) and in binary mode (b)
file = open("/content/drive/MyDrive/MSSP607/Modules/Week09/Photos/bc3.jpg", "wb")
file.write(r.content) #write tocontent of the r request
file.close()

# %%
r = requests.get('https://www.sp2.upenn.edu/wp-content/uploads/2022/03/Richard-Hartwell.png')
r.status_code == requests.codes.ok #Check if the requests was eqal to ok
# Out:
# True

# %%
#Open a file named Profile_Picture.jpg and prepare it for writing in binary format.
file = open("/content/drive/MyDrive/MSSP607/Modules/Week09/Photos/Profile_Picture.jpg", "wb")
file.write(r.content)
file.close()

# %%
#Pull a Jupyter notebook form the Molin repository in GitHub
r = requests.get('https://cdn.cnn.com/cnnnext/dam/assets/22110219164-2-joe-biden-union-station-110222-medium-tease.jpg')
r.status_code
#Status code return by the remote server status that all is good with the communication
# Out:
# 500

# %%
#Write the Jupyter notebook to the assigned directory
file = open("/content/drive/MyDrive/MSSP607/Modules/Week09/Photos/CreatingDataFrames.ipynb", "wb")
file.write(r.content)
file.close()
